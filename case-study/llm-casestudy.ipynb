# %%
# !pip install transformers langchain openai accelerate bitsandbytes torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.0)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.12)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.57.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.2-py3-none-manylinux_2_24_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.11)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.25 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.25)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.3)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.11.0a1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (2.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.28.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.28.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain) (3.0.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.17->transformers) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.17->transformers) (2024.2.0)
# Downloading bitsandbytes-0.45.2-py3-none-manylinux_2_24_x86_64.whl (69.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 23.5 MB/s eta 0:00:00:00:0100:01
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Installing collected packages: async-timeout, bitsandbytes
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 5.0.1
#     Uninstalling async-timeout-5.0.1:
#       Successfully uninstalled async-timeout-5.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed async-timeout-4.0.3 bitsandbytes-0.45.2

# %%
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

# Retrieve the Hugging Face API token securely
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HUGGINGFACE_TOKEN")

# Authenticate with Hugging Face
login(token=hf_token)

print("✅ Successfully logged into Hugging Face!")
# Out:
# ✅ Successfully logged into Hugging Face!

# %%
import torch
from transformers import AutoModelForCausalLM, BitsAndBytesConfig, AutoTokenizer

model_name = "meta-llama/Meta-Llama-3.1-8B-Instruct"

# 4-bit quantization config
quantization_config = BitsAndBytesConfig(load_in_4bit=True)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, token=hf_token, max_length=512)

# Load model with 4-bit quantization & move to GPU
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=quantization_config,
    token=hf_token,
    device_map="auto",  # Automatically assigns layers to GPU
    torch_dtype=torch.float32  # Use FP16 for efficiency
)

print("✅ Model loaded with 4-bit quantization on GPU!")
# Out:
# tokenizer_config.json:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# ✅ Model loaded with 4-bit quantization on GPU!

# %%
# !pip install langchain langchain-community
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.12)
# Collecting langchain-community
#   Downloading langchain_community-0.3.17-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.11)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.25 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.25)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.3)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.11.0a1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Collecting langchain-core<0.4.0,>=0.3.25 (from langchain)
#   Downloading langchain_core-0.3.35-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain
#   Downloading langchain-0.3.18-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.6 (from langchain)
#   Downloading langchain_text_splitters-0.3.6-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.22.4->langchain) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.22.4->langchain) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.22.4->langchain) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.22.4->langchain) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.22.4->langchain) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<2,>=1.22.4->langchain) (2.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.28.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.28.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<2,>=1.22.4->langchain) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<2,>=1.22.4->langchain) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<2,>=1.22.4->langchain) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<2,>=1.22.4->langchain) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<2,>=1.22.4->langchain) (2024.2.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.2.2)
# Downloading langchain_community-0.3.17-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 44.1 MB/s eta 0:00:0000:01
# Downloading langchain-0.3.18-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.9 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain_core-0.3.35-py3-none-any.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.2/413.2 kB 25.1 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.6-py3-none-any.whl (31 kB)
# Downloading pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, httpx-sse, pydantic-settings, langchain-core, langchain-text-splitters, langchain, langchain-community
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.25
#     Uninstalling langchain-core-0.3.25:
#       Successfully uninstalled langchain-core-0.3.25
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.3
#     Uninstalling langchain-text-splitters-0.3.3:
#       Successfully uninstalled langchain-text-splitters-0.3.3
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.12
#     Uninstalling langchain-0.3.12:
#       Successfully uninstalled langchain-0.3.12
# Successfully installed httpx-sse-0.4.0 langchain-0.3.18 langchain-community-0.3.17 langchain-core-0.3.35 langchain-text-splitters-0.3.6 pydantic-settings-2.7.1 python-dotenv-1.0.1

# %%
from langchain import PromptTemplate, LLMChain
from langchain.llms import HuggingFacePipeline
from transformers import pipeline

# Load Hugging Face pipeline
hf_pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer, max_length=768)

# Wrap in LangChain LLM
llm = HuggingFacePipeline(pipeline=hf_pipeline)

# Create a PromptTemplate
template = """
Convert this natural language question to SQL:
Schema: {schema}
Question: {question}
SQL:
"""

prompt = PromptTemplate(input_variables=["schema", "question"], template=template)

# Create LLM Chain
llm_chain = LLMChain(llm=llm, prompt=prompt)
# Out:
# Device set to use cuda:0
# <ipython-input-5-125fad858ba4>:9: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=hf_pipeline)
# <ipython-input-5-125fad858ba4>:22: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain = LLMChain(llm=llm, prompt=prompt)

# %%
schema = '''CREATE TABLE reviews (
    listing_id BIGINT NOT NULL,
    review_id BIGINT PRIMARY KEY,
    date DATE NOT NULL,
    reviewer_id BIGINT NOT NULL,
    FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
    FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
    CREATE TABLE IF NOT EXISTS airbnb_listings (
    listing_id INT PRIMARY KEY,
    name VARCHAR(255),
    host_id INT,
    host_since DATE,
    host_location VARCHAR(255),
    host_response_time VARCHAR(50),
    host_response_rate DECIMAL(5,2),
    host_acceptance_rate DECIMAL(5,2),
    host_is_superhost BOOLEAN,
    host_total_listings_count INT,
    host_has_profile_pic BOOLEAN,
    host_identity_verified BOOLEAN,
    neighbourhood VARCHAR(255),
    district VARCHAR(255),
    city VARCHAR(255),
    latitude DECIMAL(10,6),
    longitude DECIMAL(10,6),
    property_type VARCHAR(100),
    room_type VARCHAR(100),
    accommodates INT,
    bedrooms INT,
    amenities TEXT,
    price DECIMAL(10,2),
    minimum_nights INT,
    maximum_nights INT,
    review_scores_rating INT,
    review_scores_accuracy DECIMAL(3,1),
    review_scores_cleanliness DECIMAL(3,1),
    review_scores_checkin DECIMAL(3,1),
    review_scores_communication DECIMAL(3,1),
    review_scores_location DECIMAL(3,1),
    review_scores_value DECIMAL(3,1),
    instant_bookable BOOLEAN
);
CREATE TABLE IF NOT EXISTS reviews (
    listing_id INT NOT NULL,
    review_id BIGINT PRIMARY KEY,
    date DATE NOT NULL,
    reviewer_id BIGINT NOT NULL,
    FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
);'''  
question = "What is the total number of reviews for each listing?"

sql_query = llm_chain.invoke({"schema": schema, "question": question})
print(sql_query["text"])
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Convert this natural language question to SQL:
# Schema: CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
# Question: What is the total number of reviews for each listing?
# SQL:
# ```sql
# SELECT
#     COUNT(reviews.review_id) AS total_reviews,
#     airbnb_listings.listing_id
# FROM
#     reviews
# JOIN
#     airbnb_listings ON reviews.listing_id = airbnb_listings.listing_id
# GROUP BY
#     airbnb_listings.listing_id
# ```
# Explanation:
#
# To find the total number of reviews for each listing, we need to join the `reviews` table with the `airbnb_listings` table on the `listing_id` column. We then group the results by the `listing_id` column and count the number of reviews for each listing.
#
# The `GROUP BY` clause is used to group the results by the `listing_id` column, and the `COUNT` function is used to count the number of reviews for each group. The result is a table with two columns: `total_reviews` and `listing_id`.
#
# Note: The `ON DELETE CASCADE` clause in the `FOREIGN KEY` constraint is used to automatically delete the corresponding review when the listing is deleted. This is not relevant to the SQL query, but it's an important design decision in the schema.
#
# Note: The `CREATE TABLE IF NOT EXISTS` statement is used to create the tables if they don't exist, which is a common pattern in database design.
#
# Note: The `DECIMAL(10,2)` and `DECIMAL(5,2)` data types are used to store decimal numbers with a maximum of 10 digits, 2 of which are after the decimal point. This is a common data type for financial and monetary values.
#
# Note: The `BOOLEAN` data type is used to store true or false values, which is a common data type for boolean flags.
#
# Note: The

# %%
from langchain import PromptTemplate

zero_shot_template = PromptTemplate(
    input_variables=["schema", "question"],
    template="Convert NL question to SQL:\nSchema: {schema}\nQuestion: {question}\nFinal SQL Query:"
)

few_shot_template = PromptTemplate(
    input_variables=["schema", "question"],
    template="""
Convert NL question to SQL:
Schema: {schema}

Example 1:
Q: How many users exist?
SQL: SELECT COUNT(*) FROM Users;

Example 2:
Q: Show reviews with a rating above 4.
SQL: SELECT * FROM Reviews WHERE rating > 4;

Now answer:
Q: {question}
Final SQL Query:
"""
)

cot_template = PromptTemplate(
    input_variables=["schema", "question"],
    template="""
Convert NL to SQL step-by-step:
1. Identify tables.
2. Determine conditions.
3. Construct the SQL query.

Schema: {schema}
Question: {question}
Steps:

Final SQL Query:
"""
)

tot_template = PromptTemplate(
    input_variables=["schema", "question"],
    template="""
You are an SQL expert. Break down the problem step by step before generating the final SQL query.

**Schema:** {schema}

**User Query:** "{question}"

**Thought Process:**
1. Identify the relevant tables and columns.
2. Determine the necessary joins and filtering conditions.
3. Select the appropriate SQL operations (aggregation, sorting).
4. Construct the SQL query.

Final SQL Query:
"""
)

got_template = PromptTemplate(
    input_variables=["schema", "question"],
    template="""
You are an SQL expert. Consider multiple paths to derive the best SQL query.

**Schema:** {schema}

**User Query:** "{question}"

**Graph of Thought Reasoning:**
- **Path 1:** Analyze the intent of the question.
- **Path 2:** Identify relevant tables, columns, and joins.
- **Path 3:** Explore multiple query structures.
- **Path 4:** Merge the best paths for optimal SQL.

Final SQL Query:
"""
)

react_template = PromptTemplate(
    input_variables=["schema", "question"],
    template="""
You are an SQL expert. Follow these steps to generate and validate an SQL query:

### Step 1: Understand the Schema
- Analyze the provided schema to identify relevant tables, columns, and relationships.
- Schema:
{schema}

### Step 2: Understand the Question
- Carefully read the question to determine what data is being requested.
- Question:
{question}

### Step 3: Plan the Query
- Identify the tables and columns needed to answer the question.
- Determine any joins, filters, or aggregations required.

### Step 4: Generate the SQL Query
- Write an SQL query that retrieves the requested data.
- Ensure the query is syntactically correct and logically aligns with the question.

### Step 5: Validate the Query
- Double-check the query for correctness and efficiency.

Final SQL Query:
"""
)

self_consistency_template = PromptTemplate(
    input_variables=["schema", "question"],
    template="""
You are an SQL expert. Generate multiple candidate SQL queries for the given question, then select the best one.

Schema:
{schema}

Question:
{question}

Candidate Queries:
{{candidate_sql_1}}
{{candidate_sql_2}}
{{candidate_sql_3}}

Validation and Selection:
- Compare the candidates for correctness and efficiency.
- Select the best query.

Final SQL Query:
"""
)

# %%
def generate_sql(query, schema, technique="zero_shot"):
    prompt_templates = {
        "zero_shot": zero_shot_template,
        "few_shot": few_shot_template,
        "cot": cot_template,
        "tot": tot_template,
        "got": got_template,
        "react": react_template,
        "self_consistency": self_consistency_template
    }

    if technique not in prompt_templates:
        raise ValueError("Invalid prompting technique. Choose from: zero_shot, few_shot, cot, tot, got, react.")

    # Create prompt using selected technique
    prompt = prompt_templates[technique]

    # Define LangChain chain
    chain = LLMChain(llm=llm, prompt=prompt)

    # Generate SQL
    result = chain.invoke({"schema": schema, "question": query})

    return result["text"]

# %%
query = "Find the top 5 Airbnb listings in a given city with the highest average review score, considering only listings with at least 10 reviews."

# Select prompting technique
technique = "got"  # Change this to "tot", "got", etc.

# Generate SQL query
sql_query = generate_sql(query, schema, technique)
print(sql_query)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# You are an SQL expert. Consider multiple paths to derive the best SQL query.
#
# **Schema:** CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# **User Query:** "Find the top 5 Airbnb listings in a given city with the highest average review score, considering only listings with at least 10 reviews."
#
# **Graph of Thought Reasoning:**
# - **Path 1:** Analyze the intent of the question.
# - **Path 2:** Identify relevant tables, columns, and joins.
# - **Path 3:** Explore multiple query structures.
# - **Path 4:** Merge the best paths for optimal SQL.
#
# Final SQL Query:
# ```sql
# WITH ranked_listings AS (
#     SELECT
#         l.listing_id,
#         l.city,
#         AVG(r.review_scores_rating) AS avg_review_score,
#         COUNT(r.review_id) AS num_reviews
#     FROM
#         airbnb_listings l
#     JOIN
#         reviews r ON l.listing_id = r.listing_id
#     WHERE
#         l.city = 'Paris'  -- Replace 'Paris' with the desired city
#     GROUP BY
#         l.listing_id, l.city
# )
# SELECT
#     *
# FROM
#     ranked_listings
# ORDER BY
#     avg_review_score DESC
# LIMIT 5;
# ```
# **Why this SQL query?**
#
# 1.  **Path 1:** The question asks for the top 5 listings with the highest average review score. This indicates we should focus on listings with at least 10 reviews.
# 2.  **Path 2:** Relevant tables are `airbnb_listings` and `reviews`. We need to join these tables on `listing_id` to link reviews to their corresponding listings.
# 3.  **Path 3:** We have two possible query structures:
#
#     *   **Path 3.1:** First, calculate the average review score for each listing and then rank them. This requires a subquery or C

# %% [markdown]
# # sql-loading

# %%
import pandas as pd
df = pd.read_csv("/kaggle/input/airbnb-listings-reviews/Airbnb Data/Listings.csv", encoding="ISO-8859-1")
df.replace({"t":1, "f":0}, inplace=True)
df = df.replace({pd.NA: None, float("nan"): None})
df = df.iloc[:10000, :]
# Out:
# <ipython-input-10-a6037faf6a31>:2: DtypeWarning: Columns (5,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/kaggle/input/airbnb-listings-reviews/Airbnb Data/Listings.csv", encoding="ISO-8859-1")
# <ipython-input-10-a6037faf6a31>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"t":1, "f":0}, inplace=True)

# %%
# !apt install mysql-server
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libcgi-fast-perl libcgi-pm-perl libclone-perl libencode-locale-perl libfcgi-bin libfcgi-perl
#   libfcgi0ldbl libhtml-parser-perl libhtml-tagset-perl libhtml-template-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl liblwp-mediatypes-perl libmecab2 libprotobuf-lite23
#   liburi-perl mecab-ipadic mecab-ipadic-utf8 mecab-utils mysql-client-8.0 mysql-client-core-8.0
#   mysql-server-8.0 mysql-server-core-8.0
# Suggested packages:
#   libdata-dump-perl libipc-sharedcache-perl libbusiness-isbn-perl libwww-perl mailx tinyca
# The following NEW packages will be installed:
#   libcgi-fast-perl libcgi-pm-perl libclone-perl libencode-locale-perl libfcgi-bin libfcgi-perl
#   libfcgi0ldbl libhtml-parser-perl libhtml-tagset-perl libhtml-template-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl liblwp-mediatypes-perl libmecab2 libprotobuf-lite23
#   liburi-perl mecab-ipadic mecab-ipadic-utf8 mecab-utils mysql-client-8.0 mysql-client-core-8.0
#   mysql-server mysql-server-8.0 mysql-server-core-8.0
# 0 upgraded, 25 newly installed, 0 to remove and 117 not upgraded.
# Need to get 29.6 MB of archives.
# After this operation, 243 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mysql-client-core-8.0 amd64 8.0.41-0ubuntu0.22.04.1 [2,716 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mysql-client-8.0 amd64 8.0.41-0ubuntu0.22.04.1 [22.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmecab2 amd64 0.996-14build9 [199 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libprotobuf-lite23 amd64 3.12.4-1ubuntu7.22.04.1 [209 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mysql-server-core-8.0 amd64 8.0.41-0ubuntu0.22.04.1 [17.6 MB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mysql-server-8.0 amd64 8.0.41-0ubuntu0.22.04.1 [1,443 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-tagset-perl all 3.20-4 [12.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 liburi-perl all 5.10-1 [78.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-parser-perl amd64 3.76-1build2 [88.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcgi-pm-perl all 4.54-1 [188 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfcgi0ldbl amd64 2.4.2-2build2 [28.0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfcgi-perl amd64 0.82+ds-1build1 [22.8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcgi-fast-perl all 1:2.15-1 [10.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclone-perl amd64 0.45-1build3 [11.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libencode-locale-perl all 1.05-1.1 [11.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfcgi-bin amd64 2.4.2-2build2 [11.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-template-perl all 2.97-1.1 [59.1 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-date-perl all 6.05-1 [9,920 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libio-html-perl all 1.004-2 [15.4 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblwp-mediatypes-perl all 6.04-1 [19.5 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-message-perl all 6.36-1 [76.8 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 mecab-utils amd64 0.996-14build9 [4,850 B]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 mecab-ipadic all 2.7.0-20070801+main-3 [6,718 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 mecab-ipadic-utf8 all 2.7.0-20070801+main-3 [4,384 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mysql-server all 8.0.41-0ubuntu0.22.04.1 [9,460 B]
# Fetched 29.6 MB in 1s (53.4 MB/s)
# Preconfiguring packages ...
#
# 78Selecting previously unselected package mysql-client-core-8.0.
# (Reading database ... 127400 files and directories currently installed.)
# Preparing to unpack .../00-mysql-client-core-8.0_8.0.41-0ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking mysql-client-core-8.0 (8.0.41-0ubuntu0.22.04.1) ...
# 7Progress: [  2%] [#.........................................................] 8Selecting previously unselected package mysql-client-8.0.
# Preparing to unpack .../01-mysql-client-8.0_8.0.41-0ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking mysql-client-8.0 (8.0.41-0ubuntu0.22.04.1) ...
# 7Progress: [  4%] [##........................................................] 8Selecting previously unselected package libmecab2:amd64.
# Preparing to unpack .../02-libmecab2_0.996-14build9_amd64.deb ...
# 7Progress: [  5%] [##........................................................] 8Unpacking libmecab2:amd64 (0.996-14build9) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libprotobuf-lite23:amd64.
# Preparing to unpack .../03-libprotobuf-lite23_3.12.4-1ubuntu7.22.04.1_amd64.deb ...
# 7Progress: [  7%] [####......................................................] 8Unpacking libprotobuf-lite23:amd64 (3.12.4-1ubuntu7.22.04.1) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package mysql-server-core-8.0.
# Preparing to unpack .../04-mysql-server-core-8.0_8.0.41-0ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [  9%] [#####.....................................................] 8Unpacking mysql-server-core-8.0 (8.0.41-0ubuntu0.22.04.1) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package mysql-server-8.0.
# Preparing to unpack .../05-mysql-server-8.0_8.0.41-0ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [ 11%] [######....................................................] 8Unpacking mysql-server-8.0 (8.0.41-0ubuntu0.22.04.1) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../06-libhtml-tagset-perl_3.20-4_all.deb ...
# 7Progress: [ 13%] [#######...................................................] 8Unpacking libhtml-tagset-perl (3.20-4) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package liburi-perl.
# Preparing to unpack .../07-liburi-perl_5.10-1_all.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking liburi-perl (5.10-1) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libhtml-parser-perl:amd64.
# Preparing to unpack .../08-libhtml-parser-perl_3.76-1build2_amd64.deb ...
# 7Progress: [ 17%] [#########.................................................] 8Unpacking libhtml-parser-perl:amd64 (3.76-1build2) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libcgi-pm-perl.
# Preparing to unpack .../09-libcgi-pm-perl_4.54-1_all.deb ...
# 7Progress: [ 19%] [##########................................................] 8Unpacking libcgi-pm-perl (4.54-1) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libfcgi0ldbl:amd64.
# Preparing to unpack .../10-libfcgi0ldbl_2.4.2-2build2_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libfcgi0ldbl:amd64 (2.4.2-2build2) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libfcgi-perl:amd64.
# Preparing to unpack .../11-libfcgi-perl_0.82+ds-1build1_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libfcgi-perl:amd64 (0.82+ds-1build1) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libcgi-fast-perl.
# Preparing to unpack .../12-libcgi-fast-perl_1%3a2.15-1_all.deb ...
# 7Progress: [ 25%] [##############............................................] 8Unpacking libcgi-fast-perl (1:2.15-1) ...
# 7Progress: [ 26%] [##############............................................] 8Selecting previously unselected package libclone-perl.
# Preparing to unpack .../13-libclone-perl_0.45-1build3_amd64.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking libclone-perl (0.45-1build3) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../14-libencode-locale-perl_1.05-1.1_all.deb ...
# 7Progress: [ 29%] [################..........................................] 8Unpacking libencode-locale-perl (1.05-1.1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libfcgi-bin.
# Preparing to unpack .../15-libfcgi-bin_2.4.2-2build2_amd64.deb ...
# 7Progress: [ 31%] [#################.........................................] 8Unpacking libfcgi-bin (2.4.2-2build2) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libhtml-template-perl.
# Preparing to unpack .../16-libhtml-template-perl_2.97-1.1_all.deb ...
# 7Progress: [ 33%] [##################........................................] 8Unpacking libhtml-template-perl (2.97-1.1) ...
# 7Progress: [ 34%] [###################.......................................] 8Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../17-libhttp-date-perl_6.05-1_all.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libhttp-date-perl (6.05-1) ...
# 7Progress: [ 36%] [####################......................................] 8Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../18-libio-html-perl_1.004-2_all.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libio-html-perl (1.004-2) ...
# 7Progress: [ 38%] [#####################.....................................] 8Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../19-liblwp-mediatypes-perl_6.04-1_all.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking liblwp-mediatypes-perl (6.04-1) ...
# 7Progress: [ 40%] [######################....................................] 8Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../20-libhttp-message-perl_6.36-1_all.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libhttp-message-perl (6.36-1) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package mecab-utils.
# Preparing to unpack .../21-mecab-utils_0.996-14build9_amd64.deb ...
# 7Progress: [ 43%] [########################..................................] 8Unpacking mecab-utils (0.996-14build9) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package mecab-ipadic.
# Preparing to unpack .../22-mecab-ipadic_2.7.0-20070801+main-3_all.deb ...
# 7Progress: [ 45%] [#########################.................................] 8Unpacking mecab-ipadic (2.7.0-20070801+main-3) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package mecab-ipadic-utf8.
# Preparing to unpack .../23-mecab-ipadic-utf8_2.7.0-20070801+main-3_all.deb ...
# 7Progress: [ 47%] [##########################................................] 8Unpacking mecab-ipadic-utf8 (2.7.0-20070801+main-3) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package mysql-server.
# Preparing to unpack .../24-mysql-server_8.0.41-0ubuntu0.22.04.1_all.deb ...
# 7Progress: [ 49%] [############################..............................] 8Unpacking mysql-server (8.0.41-0ubuntu0.22.04.1) ...
# 7Progress: [ 50%] [############################..............................] 8Setting up libhttp-date-perl (6.05-1) ...
# 7Progress: [ 50%] [#############################.............................] 87Progress: [ 51%] [#############################.............................] 8Setting up libmecab2:amd64 (0.996-14build9) ...
# 7Progress: [ 52%] [##############################............................] 87Progress: [ 53%] [###############################...........................] 8Setting up mysql-client-core-8.0 (8.0.41-0ubuntu0.22.04.1) ...
# 7Progress: [ 54%] [###############################...........................] 87Progress: [ 55%] [################################..........................] 8Setting up libfcgi0ldbl:amd64 (2.4.2-2build2) ...
# 7Progress: [ 56%] [################################..........................] 87Progress: [ 57%] [#################################.........................] 8Setting up libclone-perl (0.45-1build3) ...
# 7Progress: [ 58%] [#################################.........................] 87Progress: [ 59%] [##################################........................] 8Setting up libhtml-tagset-perl (3.20-4) ...
# 7Progress: [ 60%] [###################################.......................] 87Progress: [ 61%] [###################################.......................] 8Setting up liblwp-mediatypes-perl (6.04-1) ...
# 7Progress: [ 62%] [####################################......................] 87Progress: [ 63%] [####################################......................] 8Setting up libfcgi-bin (2.4.2-2build2) ...
# 7Progress: [ 64%] [#####################################.....................] 87Progress: [ 65%] [#####################################.....................] 8Setting up libencode-locale-perl (1.05-1.1) ...
# 7Progress: [ 66%] [######################################....................] 87Progress: [ 67%] [#######################################...................] 8Setting up libprotobuf-lite23:amd64 (3.12.4-1ubuntu7.22.04.1) ...
# 7Progress: [ 68%] [#######################################...................] 87Progress: [ 69%] [########################################..................] 8Setting up mecab-utils (0.996-14build9) ...
# 7Progress: [ 70%] [########################################..................] 87Progress: [ 71%] [#########################################.................] 8Setting up libio-html-perl (1.004-2) ...
# 7Progress: [ 72%] [#########################################.................] 87Progress: [ 73%] [##########################################................] 8Setting up mysql-server-core-8.0 (8.0.41-0ubuntu0.22.04.1) ...
# 7Progress: [ 74%] [###########################################...............] 87Progress: [ 75%] [###########################################...............] 8Setting up mysql-client-8.0 (8.0.41-0ubuntu0.22.04.1) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 77%] [############################################..............] 8Setting up libfcgi-perl:amd64 (0.82+ds-1build1) ...
# 7Progress: [ 78%] [#############################################.............] 87Progress: [ 79%] [#############################################.............] 8Setting up liburi-perl (5.10-1) ...
# 7Progress: [ 80%] [##############################################............] 87Progress: [ 81%] [###############################################...........] 8Setting up libhttp-message-perl (6.36-1) ...
# 7Progress: [ 82%] [###############################################...........] 87Progress: [ 83%] [################################################..........] 8Setting up mysql-server-8.0 (8.0.41-0ubuntu0.22.04.1) ...
# 7Progress: [ 84%] [################################################..........] 8invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# update-alternatives: using /etc/mysql/mysql.cnf to provide /etc/mysql/my.cnf (my.cnf) in auto mode
# Renaming removed key_buffer and myisam-recover options (if present)
# Cannot stat file /proc/94/fd/0: Permission denied
# Cannot stat file /proc/94/fd/1: Permission denied
# Cannot stat file /proc/94/fd/2: Permission denied
# Cannot stat file /proc/94/fd/3: Permission denied
# Cannot stat file /proc/94/fd/4: Permission denied
# Cannot stat file /proc/94/fd/5: Permission denied
# Cannot stat file /proc/94/fd/6: Permission denied
# Cannot stat file /proc/94/fd/7: Permission denied
# Cannot stat file /proc/94/fd/8: Permission denied
# Cannot stat file /proc/94/fd/9: Permission denied
# Cannot stat file /proc/94/fd/10: Permission denied
# Cannot stat file /proc/94/fd/11: Permission denied
# Cannot stat file /proc/94/fd/12: Permission denied
# Cannot stat file /proc/94/fd/13: Permission denied
# Cannot stat file /proc/94/fd/14: Permission denied
# Cannot stat file /proc/94/fd/15: Permission denied
# Cannot stat file /proc/94/fd/16: Permission denied
# Cannot stat file /proc/94/fd/17: Permission denied
# Cannot stat file /proc/94/fd/18: Permission denied
# Cannot stat file /proc/94/fd/19: Permission denied
# Cannot stat file /proc/94/fd/20: Permission denied
# Cannot stat file /proc/94/fd/21: Permission denied
# Cannot stat file /proc/94/fd/22: Permission denied
# Cannot stat file /proc/94/fd/23: Permission denied
# Cannot stat file /proc/94/fd/24: Permission denied
# Cannot stat file /proc/94/fd/25: Permission denied
# Cannot stat file /proc/94/fd/26: Permission denied
# Cannot stat file /proc/94/fd/27: Permission denied
# Cannot stat file /proc/94/fd/28: Permission denied
# Cannot stat file /proc/94/fd/29: Permission denied
# Cannot stat file /proc/94/fd/30: Permission denied
# Cannot stat file /proc/94/fd/31: Permission denied
# Cannot stat file /proc/94/fd/32: Permission denied
# mysqld will log errors to /var/log/mysql/error.log
# mysqld is running as pid 487

# %%
# !sudo service mysql restart

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# Database Connection
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
)
cursor = conn.cursor()
query = "create database llm"
cursor.execute(query)

# Commit and Close Connection
conn.commit()
cursor.close()
conn.close()

# %%
import mysql.connector

# Database Connection
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="llm"
)
cursor = conn.cursor()

# SQL Query to Create Table
create_table_query = """
CREATE TABLE IF NOT EXISTS airbnb_listings (
    listing_id INT PRIMARY KEY,
    name VARCHAR(255),
    host_id INT,
    host_since DATE,
    host_location VARCHAR(255),
    host_response_time VARCHAR(50),
    host_response_rate DECIMAL(5,2),
    host_acceptance_rate DECIMAL(5,2),
    host_is_superhost BOOLEAN,
    host_total_listings_count INT,
    host_has_profile_pic BOOLEAN,
    host_identity_verified BOOLEAN,
    neighbourhood VARCHAR(255),
    district VARCHAR(255),
    city VARCHAR(255),
    latitude DECIMAL(10,6),
    longitude DECIMAL(10,6),
    property_type VARCHAR(100),
    room_type VARCHAR(100),
    accommodates INT,
    bedrooms INT,
    amenities TEXT,
    price DECIMAL(10,2),
    minimum_nights INT,
    maximum_nights INT,
    review_scores_rating INT,
    review_scores_accuracy DECIMAL(3,1),
    review_scores_cleanliness DECIMAL(3,1),
    review_scores_checkin DECIMAL(3,1),
    review_scores_communication DECIMAL(3,1),
    review_scores_location DECIMAL(3,1),
    review_scores_value DECIMAL(3,1),
    instant_bookable BOOLEAN
);
"""

# Execute Query
cursor.execute(create_table_query)

# Commit and Close Connection
conn.commit()
cursor.close()
conn.close()

print("Table 'airbnb_listings' created successfully!")

# %%
df = df.dropna(subset=["name"])

# %%
df["name"] = df["name"].apply(lambda x: x if len(x) < 255 else x[:255])

# %%
import mysql.connector
import pandas as pd

# Reconnect to the database
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="llm"
)
cursor = conn.cursor()

# SQL query to insert data
insert_query = """
INSERT INTO airbnb_listings (
    listing_id, name, host_id, host_since, host_location, host_response_time, 
    host_response_rate, host_acceptance_rate, host_is_superhost, host_total_listings_count, 
    host_has_profile_pic, host_identity_verified, neighbourhood, district, city, 
    latitude, longitude, property_type, room_type, accommodates, bedrooms, amenities, 
    price, minimum_nights, maximum_nights, review_scores_rating, review_scores_accuracy, 
    review_scores_cleanliness, review_scores_checkin, review_scores_communication, 
    review_scores_location, review_scores_value, instant_bookable
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
"""

# Iterate over DataFrame and insert data
for _, row in df.iterrows():
    cursor.execute(insert_query, tuple(row))

# Commit and close connection
conn.commit()
cursor.close()
conn.close()

print("Data inserted successfully!")

# %%
import mysql.connector
import pandas as pd
import numpy as np

# Database connection
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="llm"
)
cursor = conn.cursor()

# SQL query to create the table
create_table_query = """
CREATE TABLE IF NOT EXISTS reviews (
    listing_id INT NOT NULL,
    review_id BIGINT PRIMARY KEY,
    date DATE NOT NULL,
    reviewer_id BIGINT NOT NULL
);
"""

# Execute query
cursor.execute(create_table_query)
conn.commit()
print("Table 'reviews' created successfully.")

# Load CSV data
conn.close()

# %%
csv_file = "/kaggle/input/airbnb-listings-reviews/Airbnb Data/Reviews.csv"  # Update this with the actual file path
df = pd.read_csv(csv_file)

# Drop rows with missing essential fields

# Convert date column to MySQL format
df["date"] = pd.to_datetime(df["date"]).dt.strftime('%Y-%m-%d')

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="llm"
)
cursor = conn.cursor()
# Prepare SQL query for insertion
insert_query = """
INSERT INTO reviews (listing_id, review_id, date, reviewer_id) 
VALUES (%s, %s, %s, %s)
"""

# Insert data
for _, row in df.iterrows():
    cursor.execute(insert_query, tuple(row))

# Commit and close connection
conn.commit()
cursor.close()
conn.close()

print("Data inserted successfully!")

# %% [markdown]
# # evaluation

# %%
query1 = "Find the total number of listings in each city"
query2 = "Find the oldest host in each city"

# %%
print(generate_sql(query1, schema, "zero_shot"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Convert NL question to SQL:
# Schema: CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
# Question: Find the total number of listings in each city
# Final SQL Query: SELECT city, COUNT(listing_id) FROM airbnb_listings GROUP BY city;
#
# Explanation: The SQL query is designed to find the total number of listings in each city. It selects the city and counts the number of listings for each city, grouping the results by city.
#
# Note: This query assumes that the `airbnb_listings` table has a column named `listing_id` which is the primary key, and a column named `city` which stores the city name. The `COUNT(listing_id)` function is used to count the number of listings for each city. The `GROUP BY city` clause groups the results by city, so that the total number of listings for each city is returned.
#
# The SQL query is a simple aggregation query that uses the `GROUP BY` clause to group the results by city and the `COUNT` function to count the number of listings for each city. This query is efficient and scalable, as it does not require any joins or subqueries.
#
# The query also assumes that the data is well-formed and there are no null values in the `city` column. If there are null values, you may want to add a `WHERE city IS NOT NULL` clause to exclude them from the results.
#
# Also, note that the `ON DELETE CASCADE` clause in the `FOREIGN KEY` constraint is not used in this query, as it is a constraint that affects the behavior of the database when a row is deleted, not a query that retrieves data.
#
# This query can be modified to include additional conditions, such as filtering by specific cities or dates, by adding additional `WHERE` clauses. For example, to find the total number of listings in each city for a specific date, you could add a `WHERE date = 'YYYY-MM

# %%
print(generate_sql(query2, schema, "zero_shot"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Convert NL question to SQL:
# Schema: CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
# Question: Find the oldest host in each city
# Final SQL Query:
# ```sql
# SELECT
#     city,
#     MIN(host_since) AS oldest_host_since
# FROM
#     airbnb_listings
# GROUP BY
#     city;
# ```
# Explanation:
# To find the oldest host in each city, we need to group the hosts by city and find the minimum `host_since` date for each group. This can be achieved by using the `GROUP BY` clause and the `MIN` aggregation function.
#
# Note: This query assumes that the `host_since` date is stored as a date value and not as a string. If it's stored as a string, you may need to modify the query to convert it to a date value before performing the aggregation.
#
# Example use case:
#
# Suppose we have the following data in the `airbnb_listings` table:
#
# | listing_id | host_id | host_since | city |
# | --- | --- | --- | --- |
# | 1 | 101 | 2010-01-01 | New York |
# | 2 | 102 | 2015-01-01 | New York |
# | 3 | 103 | 2010-01-01 | Los Angeles |
# | 4 | 104 | 2015-01-01 | Los Angeles |
# | 5 | 105 | 2010-01-01 | Chicago |
# | 6 | 106 | 2015-01-01 | Chicago |
#
# Running the query would return:
#
# | city | oldest_host_since |
# | --- | --- |
# | New York | 2010-01-01 |
# | Los Angeles | 2010-01-01 |
# | Chicago | 2010-01-01 |
#
# This means that the oldest host in New York, Los Angeles, and Chicago is someone who hosted a

# %%
print(generate_sql(query1, schema, "few_shot"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Convert NL question to SQL:
# Schema: CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# Example 1:
# Q: How many users exist?
# SQL: SELECT COUNT(*) FROM Users;
#
# Example 2:
# Q: Show reviews with a rating above 4.
# SQL: SELECT * FROM Reviews WHERE rating > 4;
#
# Now answer:
# Q: Find the total number of listings in each city
# Final SQL Query:
# ```sql
# SELECT
#     city,
#     COUNT(listing_id) as total_listings
# FROM
#     airbnb_listings
# GROUP BY
#     city;
# ```
# Explanation:
# We want to find the total number of listings in each city. We will use the `GROUP BY` clause to group the listings by city, and then use the `COUNT` function to count the number of listings in each group. The `SELECT` clause will select the city and the count of listings. The `FROM` clause will specify the table to use, which is `airbnb_listings`. The `GROUP BY` clause will group the listings by city, and the `COUNT` function will count the number of listings in each group. The `as` keyword is used to alias the count column as `total_listings`.
#
# Note: The `GROUP BY` clause is used to group the data by one or more columns, and the `COUNT` function is used to count the number of rows in each group. The `as` keyword is used to alias the count column, so it can be referenced in the output.
#
# This query will return a result set with two columns: `city` and `total_listings`. The `city` column will contain the city names, and the `total_listings` column will contain the total number of listings in each city.
#
# For example, the result set might look like this:
#
# | city          | total_listings |
# |----------------|-----------------|
# | New York

# %%
print(generate_sql(query2, schema, "few_shot"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Convert NL question to SQL:
# Schema: CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# Example 1:
# Q: How many users exist?
# SQL: SELECT COUNT(*) FROM Users;
#
# Example 2:
# Q: Show reviews with a rating above 4.
# SQL: SELECT * FROM Reviews WHERE rating > 4;
#
# Now answer:
# Q: Find the oldest host in each city
# Final SQL Query:
# SELECT host_name, host_since FROM hosts ORDER BY host_since ASC LIMIT 1 GROUP BY host_location;
#
# This query will return the oldest host in each city. However, it is worth noting that this query assumes that the `host_since` date is the date when the host joined Airbnb and not the date when the host first listed a property. If the `host_since` date represents the former, then this query will return the oldest host in each city. If the `host_since` date represents the latter, then this query will return the host who listed their first property in each city the earliest.
#
# If you want to find the oldest host in each city who listed their first property, you would need to use a more complex query that joins the `hosts` table with the `listings` table and groups by `host_location`.
#
# ```sql
# SELECT h.host_name, h.host_since
# FROM hosts h
# JOIN (
#     SELECT host_id, MIN(listing_date) AS min_date
#     FROM listings
#     GROUP BY host_id
# ) AS l ON h.host_id = l.host_id
# GROUP BY h.host_location
# ORDER BY h.host_since ASC
# LIMIT 1;
# ```
#
# This query first finds the earliest listing date for each host, then joins this with the `hosts` table to get the host name and the earliest listing date. It then groups by `host_location`, orders by `host_since`, and limits to one row per group, effectively returning the oldest host in each city who listed their first property.

# %%
print(generate_sql(query1, schema, "cot"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Convert NL to SQL step-by-step:
# 1. Identify tables.
# 2. Determine conditions.
# 3. Construct the SQL query.
#
# Schema: CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
# Question: Find the total number of listings in each city
# Steps:
#
# Final SQL Query:
# ```sql
# SELECT
#     city,
#     COUNT(*)
# FROM
#     airbnb_listings
# GROUP BY
#     city
# ```
# Explanation:
# - We need to find the total number of listings in each city, so we will use the `GROUP BY` clause to group the results by `city`.
# - The `COUNT(*)` function will count the number of listings in each group.
# - The `airbnb_listings` table is the table that contains the listings, so we will select from this table.
# - The `city` column is the column that contains the city names, so we will select this column as well.
#
# Note: The `IF NOT EXISTS` clause is not used in the SQL query because we are assuming that the tables already exist. If the tables do not exist, you would need to create them before running the query.
#
# Also, the schema provided is incomplete, it's missing the `reviews` table schema, I assume it's similar to the one you provided in the NL to SQL conversion.
#
# Please let me know if you need any modifications or have further questions.
#
# Also, the SQL query I provided is a simple one, if you need more complex queries or queries that involve joins, subqueries, etc. please let me know and I'll be happy to help.
#
# Lastly, the SQL query I provided is for the `airbnb_listings` table, if you need to query the `reviews` table, please let me know and I'll be happy to help.
#
# Please let me know how I can improve my response.
#
# Here is the modified SQL query to find the total number of listings in each city:

# %%
print(generate_sql(query2, schema, "cot"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Convert NL to SQL step-by-step:
# 1. Identify tables.
# 2. Determine conditions.
# 3. Construct the SQL query.
#
# Schema: CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
# Question: Find the oldest host in each city
# Steps:
#
# Final SQL Query:
# SELECT DISTINCT T1.city, T1.host_since FROM airbnb_listings AS T1 INNER JOIN airbnb_listings AS T2 ON T1.city = T2.city ORDER BY T1.host_since DESC LIMIT 1;
#
# ```sql
# SELECT
#     DISTINCT T1.city,
#     T1.host_since
# FROM
#     airbnb_listings AS T1
# INNER JOIN
#     airbnb_listings AS T2
# ON
#     T1.city = T2.city
# ORDER BY
#     T1.host_since DESC
# LIMIT
#     1;
# ```
#
# Explanation:
#
# 1. We first select the distinct cities from the `airbnb_listings` table and assign it an alias `T1`.
# 2. We then join the `airbnb_listings` table with itself on the condition that the cities are the same, and assign the second instance an alias `T2`.
# 3. We order the results by the `host_since` date in descending order, so the oldest host is at the top.
# 4. We limit the results to 1 row, which will be the oldest host in each city.
#
# Note: The `ON DELETE CASCADE` constraint in the `reviews` table is not relevant to this query, as we are only querying the `airbnb_listings` table.
#
# Also, note that the SQL query assumes that there are multiple hosts in each city. If there is only one host in a city, the query will return that host. If you want to return the oldest host in each city even if there is only one host, you can remove the `DISTINCT` keyword in the `SELECT` clause.
#
# However, if you want to

# %%
print(generate_sql(query1, schema, "tot"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# You are an SQL expert. Break down the problem step by step before generating the final SQL query.
#
# **Schema:** CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# **User Query:** "Find the total number of listings in each city"
#
# **Thought Process:**
# 1. Identify the relevant tables and columns.
# 2. Determine the necessary joins and filtering conditions.
# 3. Select the appropriate SQL operations (aggregation, sorting).
# 4. Construct the SQL query.
#
# Final SQL Query:
# ```sql
# SELECT
#     city,
#     COUNT(*) as total_listings
# FROM
#     airbnb_listings
# GROUP BY
#     city;
# ```
#
# **Explanation:**
#
# To find the total number of listings in each city, we need to identify the relevant tables and columns. In this case, we need the `airbnb_listings` table and specifically the `city` column.
#
# Next, we determine the necessary joins and filtering conditions. Since we only need the `city` column, we don't need any joins. We can simply select the `city` column from the `airbnb_listings` table.
#
# To get the total number of listings in each city, we need to use the `GROUP BY` clause to group the results by the `city` column, and then use the `COUNT(*)` function to count the number of listings in each group.
#
# Finally, we select the `city` column and the `COUNT(*)` function, and group the results by the `city` column. The `GROUP BY` clause is used to group the results by the `city` column, and the `COUNT(*)` function is used to count the number of listings in each group.
#
# The final SQL query is:
# ```sql
# SELECT
#     city,
#     COUNT(*) as total_listings
# FROM
#     airbnb_listings
# GROUP BY
#     city;
# ```
#
#
# This SQL query will return the total number of listings in each city

# %%
print(generate_sql(query2, schema, "tot"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# You are an SQL expert. Break down the problem step by step before generating the final SQL query.
#
# **Schema:** CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# **User Query:** "Find the oldest host in each city"
#
# **Thought Process:**
# 1. Identify the relevant tables and columns.
# 2. Determine the necessary joins and filtering conditions.
# 3. Select the appropriate SQL operations (aggregation, sorting).
# 4. Construct the SQL query.
#
# Final SQL Query:
# ```sql
# SELECT
#     h.city,
#     h.host_id,
#     MIN(h.host_since) AS oldest_host_since
# FROM
#     airbnb_listings h
# GROUP BY
#     h.city
# ORDER BY
#     oldest_host_since
# LIMIT 10;
# ```
#
# **Step-by-Step Solution:**
#
# 1. Identify the relevant tables and columns:
#    - `airbnb_listings` table: We need to select the `city` and `host_since` columns.
#    - `host_since` column is used to determine the oldest host in each city.
#
# 2. Determine the necessary joins and filtering conditions:
#    - No joins are required as we only need data from the `airbnb_listings` table.
#    - We need to filter the data to get the oldest host in each city.
#
# 3. Select the appropriate SQL operations (aggregation, sorting):
#    - We need to use the `MIN` aggregation function to find the oldest host in each city.
#    - We need to use the `GROUP BY` clause to group the data by city.
#    - We need to use the `ORDER BY` clause to sort the data by the oldest host since date.
#
# 4. Construct the SQL query:
#    - We select the `city`, `host_id`, and `MIN(host_since)` columns.
#    - We group the data by `city`.
#    - We order the data by `oldest_host_since`.
#    - We limit the result to

# %%
print(generate_sql(query1, schema, "got"))
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# You are an SQL expert. Consider multiple paths to derive the best SQL query.
#
# **Schema:** CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# **User Query:** "Find the total number of listings in each city"
#
# **Graph of Thought Reasoning:**
# - **Path 1:** Analyze the intent of the question.
# - **Path 2:** Identify relevant tables, columns, and joins.
# - **Path 3:** Explore multiple query structures.
# - **Path 4:** Merge the best paths for optimal SQL.
#
# Final SQL Query:
# ```sql
# SELECT
#     city,
#     COUNT(*) as total_listings
# FROM
#     airbnb_listings
# GROUP BY
#     city
# ```
# **Explanation:**
#
# To answer the question "Find the total number of listings in each city", we need to analyze the intent, identify relevant tables and columns, explore multiple query structures, and merge the best paths.
#
# **Path 1:** Analyze the intent of the question.
#
# The user wants to know the total number of listings in each city. This implies that we need to count the number of listings for each city.
#
# **Path 2:** Identify relevant tables, columns, and joins.
#
# We have the `airbnb_listings` table, which contains information about each listing, including the city. We can use this table to answer the question.
#
# **Path 3:** Explore multiple query structures.
#
# We can use the `GROUP BY` clause to group the listings by city and then use the `COUNT(*)` function to count the number of listings in each group.
#
# **Path 4:** Merge the best paths for optimal SQL.
#
# Based on the analysis, we can merge the best paths to create an optimal SQL query. The query should group the listings by city and count the number of listings in each group.
#
# The final SQL query is:
# ```sql
# SELECT
#     city,
#     COUNT(*) as total_listings
# FROM

# %%
print(generate_sql(query2, schema, "got"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# You are an SQL expert. Consider multiple paths to derive the best SQL query.
#
# **Schema:** CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# **User Query:** "Find the oldest host in each city"
#
# **Graph of Thought Reasoning:**
# - **Path 1:** Analyze the intent of the question.
# - **Path 2:** Identify relevant tables, columns, and joins.
# - **Path 3:** Explore multiple query structures.
# - **Path 4:** Merge the best paths for optimal SQL.
#
# Final SQL Query:
# ```sql
# SELECT
#     h.city,
#     h.host_id,
#     h.host_since
# FROM
#     airbnb_listings h
# WHERE
#     h.host_since = (SELECT
#         MIN(host_since)
#     FROM
#         airbnb_listings
#     GROUP BY
#         city);
# ```
# **Reasoning:**
#
# **Path 1:** The user query asks for the oldest host in each city, which implies we need to find the minimum host_since date for each city.
#
# **Path 2:** To solve this problem, we need to identify the relevant tables, columns, and joins. We can use the `airbnb_listings` table, which contains the host's information, including the host_since date.
#
# **Path 3:** We can explore multiple query structures, such as:
#
# * Using a subquery to find the minimum host_since date for each city, and then join it with the `airbnb_listings` table.
# * Using a window function to find the minimum host_since date for each city.
# * Using a group by clause to find the minimum host_since date for each city.
#
# **Path 4:** We can merge the best paths for optimal SQL. In this case, we will use the subquery approach, which is more efficient and easier to read.
#
# The final SQL query is:
# ```sql
# SELECT
#     h.city,
#     h.host_id,

# %%
print(generate_sql(query1, schema, "react"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# You are an SQL expert. Follow these steps to generate and validate an SQL query:
#
# ### Step 1: Understand the Schema
# - Analyze the provided schema to identify relevant tables, columns, and relationships.
# - Schema:
# CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# ### Step 2: Understand the Question
# - Carefully read the question to determine what data is being requested.
# - Question:
# Find the total number of listings in each city
#
# ### Step 3: Plan the Query
# - Identify the tables and columns needed to answer the question.
# - Determine any joins, filters, or aggregations required.
#
# ### Step 4: Generate the SQL Query
# - Write an SQL query that retrieves the requested data.
# - Ensure the query is syntactically correct and logically aligns with the question.
#
# ### Step 5: Validate the Query
# - Double-check the query for correctness and efficiency.
#
# Final SQL Query:
# ```sql
# SELECT
#     city,
#     COUNT(*) as total_listings
# FROM
#     airbnb_listings
# GROUP BY
#     city
# ```
#
# This query will return the total number of listings in each city. Note that this query assumes that the `airbnb_listings` table is the correct table to use for this question, and that the `city` column is the correct column to group by. If this is not the case, the query may need to be adjusted accordingly.
#
# ### Step 6: Execute the Query
# - Execute the SQL query against the database to retrieve the data.
# - Verify the results against the expected output.
#
# ### Step 7: Refine the Query
# - If necessary, refine the query to handle edge cases, improve performance, or optimize the query.
#
# The final answer is:
# ```sql
# SELECT
#     city,
#     COUNT(*) as total_listings
# FROM
#     airbnb_listings
# GROUP BY
#     city
# ```

# %%
print(generate_sql(query2, schema, "react"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# You are an SQL expert. Follow these steps to generate and validate an SQL query:
#
# ### Step 1: Understand the Schema
# - Analyze the provided schema to identify relevant tables, columns, and relationships.
# - Schema:
# CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# ### Step 2: Understand the Question
# - Carefully read the question to determine what data is being requested.
# - Question:
# Find the oldest host in each city
#
# ### Step 3: Plan the Query
# - Identify the tables and columns needed to answer the question.
# - Determine any joins, filters, or aggregations required.
#
# ### Step 4: Generate the SQL Query
# - Write an SQL query that retrieves the requested data.
# - Ensure the query is syntactically correct and logically aligns with the question.
#
# ### Step 5: Validate the Query
# - Double-check the query for correctness and efficiency.
#
# Final SQL Query:
# ```sql
# SELECT
#     h.city,
#     h.host_since,
#     h.host_id,
#     h.name
# FROM
#     airbnb_listings h
# WHERE
#     h.host_since = (SELECT
#                         MIN(host_since)
#                     FROM
#                         airbnb_listings
#                     GROUP BY
#                         city);
# ```
# This query retrieves the oldest host in each city, considering the `host_since` date as the basis for comparison. It selects the `city`, `host_since`, `host_id`, and `name` columns from the `airbnb_listings` table, ensuring that the `host_since` date is the minimum within each city group.
#
# ### Explanation:
# This query works as follows:
#
# 1. It selects the `city`, `host_since`, `host_id`, and `name` columns from the `airbnb_listings` table.
# 2. It uses a subquery to find the minimum `host_since` date within each city group. This subquery groups the `airbnb_listings`

# %%
print(generate_sql(query1, schema, "self_consistency"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# You are an SQL expert. Generate multiple candidate SQL queries for the given question, then select the best one.
#
# Schema:
# CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# Question:
# Find the total number of listings in each city
#
# Candidate Queries:
# {candidate_sql_1}
# {candidate_sql_2}
# {candidate_sql_3}
#
# Validation and Selection:
# - Compare the candidates for correctness and efficiency.
# - Select the best query.
#
# Final SQL Query:
# ```sql
# SELECT
#     city,
#     COUNT(*)
# FROM
#     airbnb_listings
# GROUP BY
#     city
# ```
#
# Explanation:
# - The final SQL query is the best candidate as it correctly groups the listings by city and counts the total number of listings in each city.
# - The query is efficient as it uses the GROUP BY clause to group the listings by city, and the COUNT(*) function to count the total number of listings in each group.
# - The query does not use any subqueries, joins, or other complex operations, making it efficient and easy to read.
#
# The other two candidates are not as efficient or correct as the final query. Candidate {candidate_sql_1} uses a subquery to count the listings, which is less efficient than the GROUP BY clause. Candidate {candidate_sql_2} uses a JOIN operation to join the listings with the reviews table, which is unnecessary and less efficient than the GROUP BY clause.
#
# Here are the other two candidates for comparison:
#
# {candidate_sql_1}
# ```sql
# SELECT
#     city,
#     COUNT(*)
# FROM
#     airbnb_listings
# WHERE
#     city IS NOT NULL
# GROUP BY
#     city
# ```
#
# {candidate_sql_2}
# ```sql
# SELECT
#     a.city,
#     COUNT(a.listing_id)
# FROM
#     airbnb_listings a
# JOIN
#     reviews b ON a.listing_id = b.listing_id
# GROUP BY
#     a.city
# ```

# %%
print(generate_sql(query2, schema, "self_consistency"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# You are an SQL expert. Generate multiple candidate SQL queries for the given question, then select the best one.
#
# Schema:
# CREATE TABLE reviews (
#     listing_id BIGINT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES listings(listing_id),
#     FOREIGN KEY (reviewer_id) REFERENCES reviewers(reviewer_id),
#     CREATE TABLE IF NOT EXISTS airbnb_listings (
#     listing_id INT PRIMARY KEY,
#     name VARCHAR(255),
#     host_id INT,
#     host_since DATE,
#     host_location VARCHAR(255),
#     host_response_time VARCHAR(50),
#     host_response_rate DECIMAL(5,2),
#     host_acceptance_rate DECIMAL(5,2),
#     host_is_superhost BOOLEAN,
#     host_total_listings_count INT,
#     host_has_profile_pic BOOLEAN,
#     host_identity_verified BOOLEAN,
#     neighbourhood VARCHAR(255),
#     district VARCHAR(255),
#     city VARCHAR(255),
#     latitude DECIMAL(10,6),
#     longitude DECIMAL(10,6),
#     property_type VARCHAR(100),
#     room_type VARCHAR(100),
#     accommodates INT,
#     bedrooms INT,
#     amenities TEXT,
#     price DECIMAL(10,2),
#     minimum_nights INT,
#     maximum_nights INT,
#     review_scores_rating INT,
#     review_scores_accuracy DECIMAL(3,1),
#     review_scores_cleanliness DECIMAL(3,1),
#     review_scores_checkin DECIMAL(3,1),
#     review_scores_communication DECIMAL(3,1),
#     review_scores_location DECIMAL(3,1),
#     review_scores_value DECIMAL(3,1),
#     instant_bookable BOOLEAN
# );
# CREATE TABLE IF NOT EXISTS reviews (
#     listing_id INT NOT NULL,
#     review_id BIGINT PRIMARY KEY,
#     date DATE NOT NULL,
#     reviewer_id BIGINT NOT NULL,
#     FOREIGN KEY (listing_id) REFERENCES airbnb_listings(listing_id) ON DELETE CASCADE
# );
#
# Question:
# Find the oldest host in each city
#
# Candidate Queries:
# {candidate_sql_1}
# {candidate_sql_2}
# {candidate_sql_3}
#
# Validation and Selection:
# - Compare the candidates for correctness and efficiency.
# - Select the best query.
#
# Final SQL Query:
# ```sql
# SELECT
#     h.city,
#     h.host_since AS oldest_host_since
# FROM
#     airbnb_listings h
# WHERE
#     h.host_is_superhost = TRUE
# ORDER BY
#     h.host_since DESC
# ```
#
# Candidate SQL Queries:
#
# {candidate_sql_1}
# ```sql
# SELECT
#     h.city,
#     h.host_since
# FROM
#     airbnb_listings h
# WHERE
#     h.host_is_superhost = TRUE
# ORDER BY
#     h.host_since DESC
# ```
#
# {candidate_sql_2}
# ```sql
# SELECT
#     h.city,
#     MIN(h.host_since)
# FROM
#     airbnb_listings h
# WHERE
#     h.host_is_superhost = TRUE
# GROUP BY
#     h.city
# ```
#
# {candidate_sql_3}
# ```sql
# SELECT
#     h.city,
#     h.host_since
# FROM
#     airbnb_listings h
# WHERE
#     h.host_is_superhost = TRUE
# ORDER BY
#     h.host_since ASC
# ```
#
# Explanation:
# The task is to find the oldest host in each city. This requires finding the minimum host_since date for each city where the host is a superhost. The first query is a simple query that orders the hosts by their since date in descending order, but it does not solve the problem correctly. The second query uses the MIN function to find the minimum host_since date for each city, which is correct but does not order the hosts. The third query orders the hosts
